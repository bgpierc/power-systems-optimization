# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 50, 1000)
y = np.linspace(0, 50, 1000)

c1 = 1
c2 = 2
d1 = 1
d2 = 3
d3= 15

f = c1*x+c2*y*x

plt.plot(x, f)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a grid of x and y values
x = np.linspace(0, 50, 1000)
y = np.linspace(0, 50, 1000)
X, Y = np.meshgrid(x, y)

# Calculate the corresponding z values using the function z = f(x, y)
Z = c1*X+c2*Y*X #X**2 + Y**2

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(X, Y, Z, cmap='viridis')

# Add labels and a color bar
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Objective')
#fig.colorbar(ax.plot_surface(X, Y, Z, cmap='viridis'), ax=ax, label='Objective')

# Show the plot
plt.show()

# %%
A = np.array([[2, 5, 1, 0,0,0],
     [5, 1, 0, 1,0,0],
     [1, 0, 0, 0,1,0],
     [1, 0, 0, 0,0,-1]])
b = np.array([50,30, 8,2])
x = 4.34
y = 8.26
s1 = 50 -2*x - 5*y
s2 = 30 -5*x - y
s3 = 8-x
s4 = x-2
X = np.array([x,y,s1,s2,s3,s4])
A@X
# Out:
# array([50., 30.,  8.,  2.])
